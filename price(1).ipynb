# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline 
import warnings
from datetime import datetime

# %%
pip install jdatetime
# Out:
# Requirement already satisfied: jdatetime in /home/jupyterlab/conda/lib/python3.6/site-packages (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## آماده سازی دیتاست جهت ورود به پکیج های برنامه

# %%
import jdatetime
data = pd.read_excel('Case Study v2.xlsx' , header = 1)
print (data.head())
print ('\n Data Types:')
print (data.dtypes)
# Out:
#    Year  Month  Total Sales (lt.)   Avg. Price  Total Visitors  Year.Month
# 0  1391      1           10531680  1338.424656          109167     1391.01
# 1  1391      2           11092325  1314.441618          122675     1391.02
# 2  1391      3           11529846  1267.542544          197621     1391.03
# 3  1391      4           12470776  1241.471640          621211     1391.04
# 4  1391      5            9386417  1183.481067         1025287     1391.05
#
#  Data Types:
# Year                   int64
# Month                  int64
# Total Sales (lt.)      int64
# Avg. Price           float64
# Total Visitors         int64
# Year.Month           float64
# dtype: object

# %%
data.rename(columns = {"Year.Month":"YearMonth"} , inplace=True)

# %%
data.rename(columns = {"Total Sales (lt.)":"total-sales" , "Avg. Price":"price", "Total Visitors":"visitor-count"}, inplace=True)

# %%
data.head()
# Out:
#    Year  Month  total-sales        price  visitor-count  YearMonth
# 0  1391      1     10531680  1338.424656         109167    1391.01
# 1  1391      2     11092325  1314.441618         122675    1391.02
# 2  1391      3     11529846  1267.542544         197621    1391.03
# 3  1391      4     12470776  1241.471640         621211    1391.04
# 4  1391      5      9386417  1183.481067        1025287    1391.05

# %%
data = data.append(["YEARMONTHTIME"])
data.rename(columns = {0:"YEARMONTHTIME"} , inplace=True)
data["YEARMONTHTIME"].replace(np.nan,    jdatetime.date(1391 ,1 , 1)     , inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#   YEARMONTHTIME  Month    Year  YearMonth        price  total-sales  \
# 0    1391-01-01    1.0  1391.0    1391.01  1338.424656   10531680.0
# 1    1391-01-01    2.0  1391.0    1391.02  1314.441618   11092325.0
# 2    1391-01-01    3.0  1391.0    1391.03  1267.542544   11529846.0
# 3    1391-01-01    4.0  1391.0    1391.04  1241.471640   12470776.0
# 4    1391-01-01    5.0  1391.0    1391.05  1183.481067    9386417.0
#
#    visitor-count
# 0       109167.0
# 1       122675.0
# 2       197621.0
# 3       621211.0
# 4      1025287.0

# %%
for i in range (0 , 84):
    warnings.filterwarnings('ignore')
    data["YEARMONTHTIME"][i] = (jdatetime.date(int(data["Year"][i]), int(data["Month"][i]), 1).togregorian().strftime("%Y""-""%m"))

# %%
data.head()
# Out:
#   YEARMONTHTIME  Month    Year  YearMonth        price  total-sales  \
# 0       2012-03    1.0  1391.0    1391.01  1338.424656   10531680.0
# 1       2012-04    2.0  1391.0    1391.02  1314.441618   11092325.0
# 2       2012-05    3.0  1391.0    1391.03  1267.542544   11529846.0
# 3       2012-06    4.0  1391.0    1391.04  1241.471640   12470776.0
# 4       2012-07    5.0  1391.0    1391.05  1183.481067    9386417.0
#
#    visitor-count
# 0       109167.0
# 1       122675.0
# 2       197621.0
# 3       621211.0
# 4      1025287.0

# %%
data.to_csv("Case Study.csv")

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
data = pd.read_csv('Case Study.csv', parse_dates=['YEARMONTHTIME'], index_col='YEARMONTHTIME',date_parser=dateparse)
print(data.head())
# Out:
#                Unnamed: 0  Month    Year  YearMonth        price  total-sales  \
# YEARMONTHTIME
# 2012-03-01              0    1.0  1391.0    1391.01  1338.424656   10531680.0
# 2012-04-01              1    2.0  1391.0    1391.02  1314.441618   11092325.0
# 2012-05-01              2    3.0  1391.0    1391.03  1267.542544   11529846.0
# 2012-06-01              3    4.0  1391.0    1391.04  1241.471640   12470776.0
# 2012-07-01              4    5.0  1391.0    1391.05  1183.481067    9386417.0
#
#                visitor-count
# YEARMONTHTIME
# 2012-03-01          109167.0
# 2012-04-01          122675.0
# 2012-05-01          197621.0
# 2012-06-01          621211.0
# 2012-07-01         1025287.0

# %% [markdown]
# ## انتخاب سری زمانی مورد نظر

# %%
ts = data['price'] 
ts.head(10)
data.index
# Out:
# DatetimeIndex(['2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01',
#                '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01',
#                '2012-11-01', '2012-12-01', '2013-01-01', '2013-02-01',
#                '2013-03-01', '2013-04-01', '2013-05-01', '2013-06-01',
#                '2013-07-01', '2013-08-01', '2013-09-01', '2013-10-01',
#                '2013-11-01', '2013-12-01', '2014-01-01', '2014-02-01',
#                '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01',
#                '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01',
#                '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01',
#                '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01',
#                '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01',
#                '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01',
#                '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01',
#                '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01',
#                '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01',
#                '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01',
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01',
#                '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01',
#                '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01',
#                '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01'],
#               dtype='datetime64[ns]', name='YEARMONTHTIME', freq=None)

# %%
ts.head()
# Out:
# YEARMONTHTIME
# 2012-03-01    1338.424656
# 2012-04-01    1314.441618
# 2012-05-01    1267.542544
# 2012-06-01    1241.471640
# 2012-07-01    1183.481067
# Name: price, dtype: float64

# %%
ts['2012-03-01']
# Out:
# 1338.424655881456

# %%
ts['2012']
# Out:
# YEARMONTHTIME
# 2012-03-01    1338.424656
# 2012-04-01    1314.441618
# 2012-05-01    1267.542544
# 2012-06-01    1241.471640
# 2012-07-01    1183.481067
# 2012-08-01    1184.665733
# 2012-09-01    1473.179695
# 2012-10-01    1448.554273
# 2012-11-01    1407.730100
# 2012-12-01    1343.253912
# Name: price, dtype: float64

# %%
#from datetime import datetime 
ts[datetime(2012,3,1)]
# Out:
# 1338.424655881456

# %% [markdown]
# ## ترسیم نمودار اولیه از داده انتخابی ( آنالیز دیداری)

# %%
warnings.filterwarnings('ignore')
plt.figure(figsize=(15,6))
plt.plot(ts)

# %% [markdown]
# ## Rolling Statistics Plotting Function
# #### در این قسمت تابعی تعریف شده برای بارها بررسی دیداری
# #### _Stationarity_
# #### با استفاده از
# #### _Rolling Mean | Rolling Standard Deviation (STD)_
# #### لطفا توجه داشته باشید برای حفظ شباهت واحد به میانگین ،از واریانس استفاده نشده است

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %% [markdown]
# ##  نمودار داده همراه با نمایش میانگین و انحراف معیار
# ## رنگ آبی : داده
# ## رنگ قرمز : میانگین
# ## رنگ مشکی : انحراف معیار
# ## ودر ادامه نتایج ارزیابی در قالب مقادیر تست مانند
# ### P-value , ...
# ## آمده است .

# %%
plt.figure(figsize = (15,6))
test_stationarity(ts)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.857781e+00
# p-value                        3.467286e-07
# #Lags Used                     0.000000e+00
# Number of Observations Used    8.300000e+01
# Critical Value (1%)           -3.511712e+00
# Critical Value (5%)           -2.897048e+00
# Critical Value (10%)          -2.585713e+00
# dtype: float64

# %% [markdown]
# ## برآورد و حذف روند
# #### ما می توانیم تغییراتی را ایجاد کنیم که مقادیر بیشتر را نسبت به مقادیر کوچک تر ارزیابی کنند
# #### به همین منظور می توان از لگاریتم و یا ریشه های دوم و سوم و یا چهارم این مقادیر استفاده کرد .
# #### در اینجا از لگاریتم استفاده می کنیم.

# %%
ts_log = np.log(ts)
plt.figure(figsize=(15,6))
plt.plot(ts_log)

# %% [markdown]
# ### در این مورد ، ساده تر می توان یک روند رو به جلو را در داده ها مشاهده کرد. اما در شلوغی دیداری هنوز زیاد است.
# ### بنابراین ما می توانیم از برخی تکنیک ها برای تخمین یا مدل سازی این روند استفاده کنیم و سپس از سری حذف کنیم
# ### شایع ترین راه ها برای انجام این کار ، سه مورد زیر است
# ### _1. Aggregation_ مناسب برای میانگین گیری برای فواصل زمانی نرتب مانند ماهیانه و یا هفتگی
# ### _2. Smoothing_ مناسب برای رولینگ
# ### _3. Polynomial Fitting_ مناسب برای رگرسیون
# ### ما در این بخش از تکنیک دوم استفاده خواهیم کرد

# %% [markdown]
# ## Moving Average  ( Smotthing Way No1 )

# %% [markdown]
# ## ترسیم : میانگین متحرک

# %%
moving_avg = ts_log.rolling(12).mean()
plt.figure(figsize=(15,6))
plt.plot(ts_log)
plt.plot(moving_avg, color='red')

# %% [markdown]
# ## بررسی تفاوت حاصل از لگاریتم گرفتن

# %%
ts_log_moving_avg_diff = ts_log - moving_avg
ts_log_moving_avg_diff.dropna(inplace=True)
plt.figure(figsize=(15,6))
test_stationarity(ts_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.737869e+00
# p-value                        6.375991e-07
# #Lags Used                     0.000000e+00
# Number of Observations Used    7.200000e+01
# Critical Value (1%)           -3.524624e+00
# Critical Value (5%)           -2.902607e+00
# Critical Value (10%)          -2.588679e+00
# dtype: float64

# %% [markdown]
# ## Exponentially Weighted Moving Average
# ## میانگین متحرک وزنی نمایی

# %%
expwighted_avg = ts_log.ewm(12).mean()
plt.figure(figsize=(15,6))
plt.plot(ts_log)
plt.plot(expwighted_avg, color='red')

# %% [markdown]
# ## بررسی تفاوت حاصل از لگاریتم گرفتن

# %%
ts_log_ewma_diff = ts_log - expwighted_avg
plt.figure(figsize=(15,6))
test_stationarity(ts_log_ewma_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.177760e+00
# p-value                        6.567160e-08
# #Lags Used                     0.000000e+00
# Number of Observations Used    8.300000e+01
# Critical Value (1%)           -3.511712e+00
# Critical Value (5%)           -2.897048e+00
# Critical Value (10%)          -2.585713e+00
# dtype: float64

# %% [markdown]
# ## Eliminating Trend and Seasonality
# ### _Differencing_

# %%
ts_log_diff = ts_log - ts_log.shift()
plt.figure(figsize=(15,6))
plt.plot(ts_log_diff)

# %%
ts_log_diff.dropna(inplace=True)
plt.figure(figsize=(15,6))
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.971464e+00
# p-value                        8.643030e-10
# #Lags Used                     4.000000e+00
# Number of Observations Used    7.800000e+01
# Critical Value (1%)           -3.517114e+00
# Critical Value (5%)           -2.899375e+00
# Critical Value (10%)          -2.586955e+00
# dtype: float64

# %%
ts_log_diff.dropna(inplace=True)
plt.figure(figsize=(15,6))
test_stationarity(ts_log_diff)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.971464e+00
# p-value                        8.643030e-10
# #Lags Used                     4.000000e+00
# Number of Observations Used    7.800000e+01
# Critical Value (1%)           -3.517114e+00
# Critical Value (5%)           -2.899375e+00
# Critical Value (10%)          -2.586955e+00
# dtype: float64

# %% [markdown]
# ### _Decomposing_

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid
plt.figure(figsize=(15,6))
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
##########################
ts_log_decompose = residual
ts_log_decompose.dropna(inplace=True)
plt.figure(figsize=(15,6))
test_stationarity(ts_log_decompose)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.799612e+00
# p-value                        2.254552e-09
# #Lags Used                     0.000000e+00
# Number of Observations Used    7.100000e+01
# Critical Value (1%)           -3.526005e+00
# Critical Value (5%)           -2.903200e+00
# Critical Value (10%)          -2.588995e+00
# dtype: float64

# %% [markdown]
# ## _The Dickey-Fuller test statistic is significantly lower than the 1% critical value. So this TS is very close to stationary._

# %% [markdown]
# ## در نتیجه انتخاب این سری زمانی نامتناسب است و باید از رگرسیون برای پیش بینی استفاده کرد .
# ## برای مشاهده و درک بهتر این موضوع روند سری زمانی را ادامه میدهیم

# %% [markdown]
# ## آنچه که در رابطه با مدل پیش بینی قابل شرح است :
# ## _Auto-Regressive Integrated Moving Averages = ARIMA Model_
# ### _1. Number of AR (Auto-Regressive) terms (p)_
# ### _2. Number of MA (Moving Average) terms (q)_
# ### _3. Number of Differences (d)_
# ## بنابراین ، نیاز به تعیین مقادیر ذکر شده داریم که با استفاده از دو نمودار در ادامه ، این مهم صورت می پذیرد.

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(ts_log_diff, nlags=20)
lag_pacf = pacf(ts_log_diff, nlags=20, method='ols')

# %% [markdown]
# ## ACF  نمودار
# ## PACF  و نمودار

# %%
#Plot ACF: 
plt.figure(figsize=(20,6))
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')


#Plot PACF:
plt.figure(figsize=(15,6))
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# ## همانطور که در دو نمودار می بینیم ، اولین محل تلاقی نمودار با اولین خط افقی از سطح بالا مقدار
# ## را نشان می دهد P
# ## که برابر است با 2
# ## و همینطور است در رابطه با مقدار
# ## q
# ## بنابراین در ادامه به ترسیم نمودارهای
# ## AR ' MA
# ## و ترکیبی از هر دو خواهیم پرداخت.

# %% [markdown]
# ## AR  بررسی

# %%
from statsmodels.tsa.arima_model import ARIMA
warnings.filterwarnings('ignore')
model = ARIMA(ts_log, order=(2, 1, 0))  
results_AR = model.fit(disp=-1)  
plt.figure(figsize=(15,6))
plt.plot(ts_log_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS: 0.4215')

# %% [markdown]
# ## MA بررسی

# %%
warnings.filterwarnings('ignore')
model = ARIMA(ts_log, order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.figure(figsize=(15,6))
plt.plot(ts_log_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS: 0.3398')

# %% [markdown]
# ## ترکیبی

# %%
for p in range(6):
    for d in range(2):
        for q in range(4):
            try:
                warnings.filterwarnings('ignore')
                model = ARIMA(ts_log, order=(p, d, q))  
                results_ARIMA = model.fit(disp=-1)  
            except:
                pass
plt.figure(figsize=(15,6))
plt.plot(ts_log_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_ARIMA.fittedvalues-ts_log_diff)**2))
# Out:
# Text(0.5, 1.0, 'RSS: 0.3287')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
predictions_MA_diff = pd.Series(results_MA.fittedvalues, copy=True)
print(predictions_MA_diff.head())
predictions_AR_diff = pd.Series(results_AR.fittedvalues, copy=True)
print(predictions_AR_diff.head())
# Out:
# YEARMONTHTIME
# 2012-04-01   -0.000544
# 2012-05-01    0.003768
# 2012-06-01    0.014569
# 2012-07-01    0.020417
# 2012-08-01    0.035622
# dtype: float64
# YEARMONTHTIME
# 2012-04-01   -0.000551
# 2012-05-01    0.003954
# 2012-06-01    0.017487
# 2012-07-01    0.025581
# 2012-08-01    0.043430
# dtype: float64
# YEARMONTHTIME
# 2012-04-01   -0.001077
# 2012-05-01    0.003027
# 2012-06-01    0.013304
# 2012-07-01    0.012889
# 2012-08-01    0.017341
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())

predictions_MA_diff_cumsum = predictions_MA_diff.cumsum()
print(predictions_MA_diff_cumsum.head())

predictions_AR_diff_cumsum = predictions_AR_diff.cumsum()
print(predictions_AR_diff_cumsum.head())
# Out:
# YEARMONTHTIME
# 2012-04-01   -0.000544
# 2012-05-01    0.003224
# 2012-06-01    0.017793
# 2012-07-01    0.038210
# 2012-08-01    0.073833
# dtype: float64
# YEARMONTHTIME
# 2012-04-01   -0.000551
# 2012-05-01    0.003402
# 2012-06-01    0.020889
# 2012-07-01    0.046470
# 2012-08-01    0.089900
# dtype: float64
# YEARMONTHTIME
# 2012-04-01   -0.001077
# 2012-05-01    0.001950
# 2012-06-01    0.015254
# 2012-07-01    0.028142
# 2012-08-01    0.045483
# dtype: float64

# %%
warnings.filterwarnings('ignore')
predictions_ARIMA_log = pd.Series(ts_log.ix[0], index=ts_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
print(predictions_ARIMA_log.head())

predictions_MA_log = pd.Series(ts_log.ix[0], index=ts_log.index)
predictions_MA_log = predictions_MA_log.add(predictions_MA_diff_cumsum,fill_value=0)
print(predictions_MA_log.head())

predictions_AR_log = pd.Series(ts_log.ix[0], index=ts_log.index)
predictions_AR_log = predictions_AR_log.add(predictions_AR_diff_cumsum,fill_value=0)
print(predictions_AR_log.head())
# Out:
# YEARMONTHTIME
# 2012-03-01    7.199249
# 2012-04-01    7.198705
# 2012-05-01    7.202473
# 2012-06-01    7.217042
# 2012-07-01    7.237459
# dtype: float64
# YEARMONTHTIME
# 2012-03-01    7.199249
# 2012-04-01    7.198697
# 2012-05-01    7.202651
# 2012-06-01    7.220138
# 2012-07-01    7.245719
# dtype: float64
# YEARMONTHTIME
# 2012-03-01    7.199249
# 2012-04-01    7.198172
# 2012-05-01    7.201199
# 2012-06-01    7.214502
# 2012-07-01    7.227391
# dtype: float64

# %% [markdown]
# ##  ARIMA       ترسیم نمودار نهایی مدل پیش بینی و مدل داده اصلی

# %%
warnings.filterwarnings('ignore')
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.figure(figsize=(15,6))
plt.plot(ts)
plt.plot(predictions_ARIMA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_ARIMA-ts)**2)/len(ts)))
# Out:
# Text(0.5, 1.0, 'RMSE: 241.7099')

# %% [markdown]
# ##  MA       ترسیم نمودار نهایی مدل پیش بینی و مدل داده اصلی

# %%
warnings.filterwarnings('ignore')
predictions_MA = np.exp(predictions_MA_log)
plt.figure(figsize=(15,6))
plt.plot(ts)
plt.plot(predictions_MA)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_MA-ts)**2)/len(ts)))
# Out:
# Text(0.5, 1.0, 'RMSE: 238.5553')

# %% [markdown]
# ##  AR       ترسیم نمودار نهایی مدل پیش بینی و مدل داده اصلی

# %%
warnings.filterwarnings('ignore')
predictions_AR = np.exp(predictions_AR_log)
plt.figure(figsize=(15,6))
plt.plot(ts)
plt.plot(predictions_AR)
plt.title('RMSE: %.4f'% np.sqrt(sum((predictions_AR-ts)**2)/len(ts)))
# Out:
# Text(0.5, 1.0, 'RMSE: 108.8940')

# %%
warnings.filterwarnings('ignore')
results_AR.predict(start=datetime(2019,3,1), end=datetime(2020,2,1), exog=None, dynamic=False)
# Out:
# 2019-03-01    0.023135
# 2019-04-01   -0.000371
# 2019-05-01   -0.006859
# 2019-06-01    0.000478
# 2019-07-01   -0.000207
# 2019-08-01   -0.001693
# 2019-09-01   -0.001094
# 2019-10-01   -0.000930
# 2019-11-01   -0.001116
# 2019-12-01   -0.001099
# 2020-01-01   -0.001061
# 2020-02-01   -0.001076
# Freq: MS, dtype: float64

# %% [markdown]
# ## همانطور که مشاهده شد ، برای
# ## ARIMA ' MA ' AR
# ## OverFitting هم موارد
# ## UnderFitting  و هم موارد
# ## به وفور وجود دارد .
# ## برای حل این تمرین با استفاده از سری زمانی ، روند ادامه پیدا کرد و از بین مدل های ذکر شده در نهایت مناسب ترین
# ## AR  که می باشد انتخاب گردید .
